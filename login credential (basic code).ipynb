# %%
#credential program
email=input("enter yoyr registerd email: ")
password=input("enter password : ")
if email==('tejasva.work@gmail.com') and password == ('123456'):
  print("login succesfullt")
elif email==('tejasva.work@gmail.com') and password!=('123456'):
    print("incorrect password")
    password = input("enter password again : ")
    if password==('123456'):
      print("login cuccesfully")
    else:
      print("try again")
elif email!=('tejasva.work@gmail.com') and password ==('123456'):
    print('incorrect email')
    email = input("enter email again : ")
    password = input("enter password again : ")
    if email==('tejasva.work@gmail.com') and password==('123456'):
      print("login cuccesfully")
    else:
      print("try again")
else:
  print("wrong credential")
# Out:
# enter yoyr registerd email: tejasva.work@gmail.com
# enter password : 1234
# incorrect password
# enter password again123456
# login cuccesfully
